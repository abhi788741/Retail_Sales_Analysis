# %% [markdown]
# # Data Acquisition & Loading

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\kapur\\Downloads\\retail_sales_dataset\\retail_sales_dataset.csv")
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 0           3              50           150
# 1           2             500          1000
# 2           1              30            30
# 3           1             500           500
# 4           2              50           100
# ..        ...             ...           ...
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120
#
# [1000 rows x 9 columns]

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# # Data Cleaning

# %%
df.rename(columns={"Transaction ID":"Transaction_ID","Customer ID":"Customer_ID","Product Category":"Product_Category",
                   "Price per Unit":"Price_per_Unit","Total Amount":"Total_Amount"},inplace=True)

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Gender', 'Age',
#        'Product_Category', 'Quantity', 'Price_per_Unit', 'Total_Amount'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Transaction_ID      0
# Date                0
# Customer_ID         0
# Gender              0
# Age                 0
# Product_Category    0
# Quantity            0
# Price_per_Unit      0
# Total_Amount        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      Transaction_ID        Date Customer_ID  Gender  Age Product_Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price_per_Unit  Total_Amount
# 0           3              50           150
# 1           2             500          1000
# 2           1              30            30
# 3           1             500           500
# 4           2              50           100
# ..        ...             ...           ...
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120
#
# [1000 rows x 9 columns]

# %%
df["Product_Category"]=df["Product_Category"].str.strip()

# %% [markdown]
# # Data Transformation & Feature Engineering

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df["Year"]=pd.to_datetime(df["Date"]).dt.year

# %%
df["Month"]=pd.to_datetime(df["Date"]).dt.month_name()

# %%
df["Day_of_Week"]=pd.to_datetime(df["Date"]).dt.day_name()

# %%
df["Quarter"]=pd.to_datetime(df["Date"]).dt.to_period('Q')

# %%
df["Age_Group"]=df["Age"].apply(lambda x: "Senior" if x>=60 else ("Adult" if x>30 else "Young"))

# %%
df["Sales_Classification"]=df["Total_Amount"].apply(lambda x: "High" if x>=1500 else ("Medium" if x>=500 else "Low"))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Transaction_ID        1000 non-null   int64
#  1   Date                  1000 non-null   datetime64[ns]
#  2   Customer_ID           1000 non-null   object
#  3   Gender                1000 non-null   object
#  4   Age                   1000 non-null   int64
#  5   Product_Category      1000 non-null   object
#  6   Quantity              1000 non-null   int64
#  7   Price_per_Unit        1000 non-null   int64
#  8   Total_Amount          1000 non-null   int64
#  9   Year                  1000 non-null   int32
#  10  Month                 1000 non-null   object
#  11  Day_of_Week           1000 non-null   object
#  12  Quarter               1000 non-null   period[Q-DEC]
#  13  Age_Group             1000 non-null   object
#  14  Sales_Classification  1000 non-null   object
# dtypes: datetime64[ns](1), int32(1), int64(5), object(7), period[Q-DEC](1)
# memory usage: 113.4+ KB

# %% [markdown]
# # Data Filtering

# %%
# Customers whose age is between 40 and 50
df[(df["Age"]>40) & (df["Age"]<=50)]
# Out:
#      Transaction_ID       Date Customer_ID  Gender  Age Product_Category  \
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 5                 6 2023-04-25     CUST006  Female   45           Beauty
# 6                 7 2023-03-13     CUST007    Male   46         Clothing
# 14               15 2023-01-16     CUST015  Female   42      Electronics
# 17               18 2023-04-30     CUST018  Female   47      Electronics
# ..              ...        ...         ...     ...  ...              ...
# 985             986 2023-01-17     CUST986  Female   49         Clothing
# 988             989 2023-12-28     CUST989  Female   44      Electronics
# 992             993 2023-02-06     CUST993  Female   48      Electronics
# 994             995 2023-04-30     CUST995  Female   41         Clothing
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price_per_Unit  Total_Amount  Year     Month Day_of_Week  \
# 2           1              30            30  2023   January      Friday
# 5           1              30            30  2023     April     Tuesday
# 6           2              25            50  2023     March      Monday
# 14          4             500          2000  2023   January      Monday
# 17          2              25            50  2023     April      Sunday
# ..        ...             ...           ...   ...       ...         ...
# 985         2             500          1000  2023   January     Tuesday
# 988         1              25            25  2023  December    Thursday
# 992         3              50           150  2023  February      Monday
# 994         1              30            30  2023     April      Sunday
# 999         4              30           120  2023     April   Wednesday
#
#     Quarter Age_Group Sales_Classification
# 2    2023Q1     Adult                  Low
# 5    2023Q2     Adult                  Low
# 6    2023Q1     Adult                  Low
# 14   2023Q1     Adult                 High
# 17   2023Q2     Adult                  Low
# ..      ...       ...                  ...
# 985  2023Q1     Adult               Medium
# 988  2023Q4     Adult                  Low
# 992  2023Q1     Adult                  Low
# 994  2023Q2     Adult                  Low
# 999  2023Q2     Adult                  Low
#
# [221 rows x 15 columns]

# %%
#Female buying which product most
df[(df["Gender"]=='Female') & (df["Product_Category"]=='Clothing')]
# Out:
#      Transaction_ID       Date Customer_ID  Gender  Age Product_Category  \
# 1                 2 2023-02-27     CUST002  Female   26         Clothing
# 9                10 2023-10-07     CUST010  Female   52         Clothing
# 16               17 2023-04-22     CUST017  Female   27         Clothing
# 18               19 2023-09-16     CUST019  Female   62         Clothing
# 22               23 2023-04-12     CUST023  Female   35         Clothing
# ..              ...        ...         ...     ...  ...              ...
# 985             986 2023-01-17     CUST986  Female   49         Clothing
# 986             987 2023-04-29     CUST987  Female   30         Clothing
# 987             988 2023-05-28     CUST988  Female   63         Clothing
# 990             991 2023-12-26     CUST991  Female   34         Clothing
# 994             995 2023-04-30     CUST995  Female   41         Clothing
#
#      Quantity  Price_per_Unit  Total_Amount  Year      Month Day_of_Week  \
# 1           2             500          1000  2023   February      Monday
# 9           4              50           200  2023    October    Saturday
# 16          4              25           100  2023      April    Saturday
# 18          2              25            50  2023  September    Saturday
# 22          4              30           120  2023      April   Wednesday
# ..        ...             ...           ...   ...        ...         ...
# 985         2             500          1000  2023    January     Tuesday
# 986         3             300           900  2023      April    Saturday
# 987         3              25            75  2023        May      Sunday
# 990         2              50           100  2023   December     Tuesday
# 994         1              30            30  2023      April      Sunday
#
#     Quarter Age_Group Sales_Classification
# 1    2023Q1     Young               Medium
# 9    2023Q4     Adult                  Low
# 16   2023Q2     Young                  Low
# 18   2023Q3    Senior                  Low
# 22   2023Q2     Adult                  Low
# ..      ...       ...                  ...
# 985  2023Q1     Adult               Medium
# 986  2023Q2     Young               Medium
# 987  2023Q2    Senior                  Low
# 990  2023Q4     Adult                  Low
# 994  2023Q2     Adult                  Low
#
# [174 rows x 15 columns]

# %%
#Customers Contributing with Low Sales
df[df["Sales_Classification"]=='Low']
# Out:
#      Transaction_ID       Date Customer_ID  Gender  Age Product_Category  \
# 0                 1 2023-11-24     CUST001    Male   34           Beauty
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 4                 5 2023-05-06     CUST005    Male   30           Beauty
# 5                 6 2023-04-25     CUST006  Female   45           Beauty
# 6                 7 2023-03-13     CUST007    Male   46         Clothing
# ..              ...        ...         ...     ...  ...              ...
# 995             996 2023-05-16     CUST996    Male   62         Clothing
# 996             997 2023-11-17     CUST997    Male   52           Beauty
# 997             998 2023-10-29     CUST998  Female   23           Beauty
# 998             999 2023-12-05     CUST999  Female   36      Electronics
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price_per_Unit  Total_Amount  Year     Month Day_of_Week  \
# 0           3              50           150  2023  November      Friday
# 2           1              30            30  2023   January      Friday
# 4           2              50           100  2023       May    Saturday
# 5           1              30            30  2023     April     Tuesday
# 6           2              25            50  2023     March      Monday
# ..        ...             ...           ...   ...       ...         ...
# 995         1              50            50  2023       May     Tuesday
# 996         3              30            90  2023  November      Friday
# 997         4              25           100  2023   October      Sunday
# 998         3              50           150  2023  December     Tuesday
# 999         4              30           120  2023     April   Wednesday
#
#     Quarter Age_Group Sales_Classification
# 0    2023Q4     Adult                  Low
# 2    2023Q1     Adult                  Low
# 4    2023Q2     Young                  Low
# 5    2023Q2     Adult                  Low
# 6    2023Q1     Adult                  Low
# ..      ...       ...                  ...
# 995  2023Q2    Senior                  Low
# 996  2023Q4     Adult                  Low
# 997  2023Q4     Young                  Low
# 998  2023Q4     Adult                  Low
# 999  2023Q2     Adult                  Low
#
# [650 rows x 15 columns]

# %%
# Checking Calculation correction of Total Amount
df[df["Total_Amount"]==df["Quantity"]* df["Price_per_Unit"]]
# Out:
#      Transaction_ID       Date Customer_ID  Gender  Age Product_Category  \
# 0                 1 2023-11-24     CUST001    Male   34           Beauty
# 1                 2 2023-02-27     CUST002  Female   26         Clothing
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 3                 4 2023-05-21     CUST004    Male   37         Clothing
# 4                 5 2023-05-06     CUST005    Male   30           Beauty
# ..              ...        ...         ...     ...  ...              ...
# 995             996 2023-05-16     CUST996    Male   62         Clothing
# 996             997 2023-11-17     CUST997    Male   52           Beauty
# 997             998 2023-10-29     CUST998  Female   23           Beauty
# 998             999 2023-12-05     CUST999  Female   36      Electronics
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price_per_Unit  Total_Amount  Year     Month Day_of_Week  \
# 0           3              50           150  2023  November      Friday
# 1           2             500          1000  2023  February      Monday
# 2           1              30            30  2023   January      Friday
# 3           1             500           500  2023       May      Sunday
# 4           2              50           100  2023       May    Saturday
# ..        ...             ...           ...   ...       ...         ...
# 995         1              50            50  2023       May     Tuesday
# 996         3              30            90  2023  November      Friday
# 997         4              25           100  2023   October      Sunday
# 998         3              50           150  2023  December     Tuesday
# 999         4              30           120  2023     April   Wednesday
#
#     Quarter Age_Group Sales_Classification
# 0    2023Q4     Adult                  Low
# 1    2023Q1     Young               Medium
# 2    2023Q1     Adult                  Low
# 3    2023Q2     Adult               Medium
# 4    2023Q2     Young                  Low
# ..      ...       ...                  ...
# 995  2023Q2    Senior                  Low
# 996  2023Q4     Adult                  Low
# 997  2023Q4     Young                  Low
# 998  2023Q4     Adult                  Low
# 999  2023Q2     Adult                  Low
#
# [1000 rows x 15 columns]

# %% [markdown]
# # EDA & Data Visualization Insights

# %%
Total_Transaction=df["Transaction_ID"].count()
Total_Transaction
# Out:
# np.int64(1000)

# %%
Total_Customers=df["Customer_ID"].nunique()
Total_Customers
# Out:
# 1000

# %%
Total_Sales=df["Total_Amount"].sum()
Total_Sales
# Out:
# np.int64(456000)

# %%
Average_sale=df["Total_Amount"].mean()
Average_sale
# Out:
# np.float64(456.0)

# %%
Quantity_Sold=df["Quantity"].sum()
Quantity_Sold
# Out:
# np.int64(2514)

# %%
customer_by_gender=df.groupby("Gender")["Customer_ID"].count()
customer_by_gender
# Out:
# Gender
# Female    510
# Male      490
# Name: Customer_ID, dtype: int64

# %%
customer_by_gender.plot(kind='pie',autopct='%1.1f%%',colors={'green','pink'})
plt.title("Customers by Gender")
plt.ylabel("")
plt.legend()
plt.savefig("customer_by_gender.png")
plt.show()

# %% [raw]
# Observation = 51% of customers are female, showing that women are purxhasing than men.

# %%
Sales_by_Category=df.groupby("Product_Category")["Total_Amount"].sum()
Sales_by_Category
# Out:
# Product_Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total_Amount, dtype: int64

# %%
Sales_by_Category.plot(kind='bar',color='violet')
plt.title("Revenue by Product Category")
plt.ylabel("")
plt.savefig("Sales_by_Category.png")
plt.show()

# %% [raw]
# Observation = The Electronics category generates the highest revenue,
#               showing that customers buying electronics products more than other product.

# %%
sales_by_gender=df.groupby("Gender")["Total_Amount"].sum()
sales_by_gender
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total_Amount, dtype: int64

# %%
sales_by_gender.plot(kind='bar')
plt.title("Sales by Gender")
plt.ylabel("Total Sales")
plt.savefig("sales_by_gender.png")
plt.show()

# %% [raw]
# Observation = Females are genrating more sales than Males.

# %%
high_sales_by_month=df.groupby(["Month","Year"])["Total_Amount"].sum().sort_values(ascending=False).head(6)
high_sales_by_month
# Out:
# Month     Year
# May       2023    53150
# October   2023    46580
# December  2023    44690
# February  2023    44060
# August    2023    36960
# June      2023    36715
# Name: Total_Amount, dtype: int64

# %%
high_sales_by_month.plot(kind='line',marker='.',color='orange')
#plt.xticks(rotation=45)
plt.title("Highest Sales by Month")
plt.ylabel("Total Sales")
plt.grid()
plt.legend()
plt.xticks(rotation=45)
plt.savefig("high_sales_by_month.png")
plt.show()

# %% [raw]
# Observation = Sales peak in May, indicating that this month has the highest customer activity compared to other months.

# %%
low_sales_by_month=df.groupby(["Month","Year"])["Total_Amount"].sum().sort_values().head(6)
low_sales_by_month
# Out:
# Month      Year
# January    2024     1530
# September  2023    23620
# March      2023    28990
# April      2023    33870
# November   2023    34920
# January    2023    35450
# Name: Total_Amount, dtype: int64

# %%
low_sales_by_month.plot(kind='line',marker='*',color='orange')
plt.title("Lowest Sales by Month")
plt.ylabel("Total Sales")
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.savefig("low_sales_by_month.png")
plt.show()

# %% [raw]
# Observation = September sets records of the lowest sales compared to other months, indicating a seasonal dip in revenue.

# %%
sales_by_quarter=df.groupby("Quarter")["Total_Amount"].sum()
sales_by_quarter
# Out:
# Quarter
# 2023Q1    108500
# 2023Q2    123735
# 2023Q3     96045
# 2023Q4    126190
# 2024Q1      1530
# Freq: Q-DEC, Name: Total_Amount, dtype: int64

# %%
sales_by_quarter.plot(kind='barh',color='purple')
plt.title("Sales by Quarter of Year")
plt.xlabel("Total Sales")
plt.legend()
plt.savefig("sales_by_quarter.png")
plt.show()

# %% [raw]
# Observation = Quarter 4 of 2023 Year records the highest sales, indicating a peak in customer purchases during this period
#               Possibly it can be due to Festival because Quarter is full of festivals.

# %%
sales_by_agegroup=df.groupby("Age_Group")["Total_Amount"].sum()
sales_by_agegroup
# Out:
# Age_Group
# Adult     278240
# Senior     44815
# Young     132945
# Name: Total_Amount, dtype: int64

# %%
sales_by_agegroup.plot(kind='pie',autopct="%1.1f%%",colors={'orange','red','brown'})
plt.title("Sales by Age Group")
plt.ylabel("")
plt.legend()
plt.savefig("sales_by_agegroup.png")
plt.show()

# %% [raw]
# Observation = 61% of Customers are Adult contribute the highest sales, while Senior customers have the lowest,
#               indicating adults are the most active buyers.

# %%
sales_by_day=df.groupby("Day_of_Week")["Total_Amount"].sum()
sales_by_day
# Out:
# Day_of_Week
# Friday       66290
# Monday       70250
# Saturday     78815
# Sunday       58600
# Thursday     53835
# Tuesday      69440
# Wednesday    58770
# Name: Total_Amount, dtype: int64

# %%
sales_by_day.plot(kind='bar',color='orange')
plt.title("Sales by Day of Week")
plt.ylabel("Total Sales")
plt.legend()
plt.xticks(rotation=45)
plt.savefig("sales_by_day.png")
plt.show()

# %% [raw]
# Observation = Sales significantly increase on Saturdays, while Thursdays show a noticeable drop in sales.

# %%
sns.scatterplot(x=df["Quantity"],y=df["Total_Amount"],hue=df["Product_Category"])
plt.title("Quantity Vs Total Amount")
plt.savefig("Quantity_Vs_Amount.png")
plt.show()

# %% [raw]
# Observation = The scatter plot of Quantity vs Total Amount shows a positive relationship,
#               indicating that customers who buy more units tend to spend more overall.

# %%
Revenue_by_category_gender=df.groupby(["Product_Category","Gender"])["Total_Amount"].sum()
Revenue_by_category_gender
# Out:
# Product_Category  Gender
# Beauty            Female    74830
#                   Male      68685
# Clothing          Female    81275
#                   Male      74305
# Electronics       Female    76735
#                   Male      80170
# Name: Total_Amount, dtype: int64

# %%
Revenue_by_category_gender.plot(kind='bar',color='brown')
plt.title("Revenue by Category & Gender")
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Observation= Females are purchasing clothes more than other products.
#              Males are purchasing Electronics items more than other products.
